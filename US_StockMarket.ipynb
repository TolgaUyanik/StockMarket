# %% [markdown]
# # US Stock Market
#
# ## 🚨 QUICK SIGNAL REFERENCE
#
# | Indicator       | Buy Signal                | Sell Signal               | Overbought       | Oversold        |
# |-----------------|---------------------------|---------------------------|------------------|-----------------|
# | **RSI**         | Cross > 30                | Cross < 70                | > 70             | < 30            |
# | **Stoch**       | %K > %D in < 20           | %K < %D in > 80           | > 80             | < 20            |
# | **StochRSI**    | Cross > 20                | Cross < 80                | > 80             | < 20            |
# | **StochRSI_K**  | Cross > StochRSI_D        | Cross < StochRSI_D        | > 80             | < 20            |
# | **StochRSI_D**  | Smoother confirmation     | Smoother confirmation     | > 80             | < 20            |
# | **MACD**        | Line > Signal             | Line < Signal             | -                | -               |
# | **MACDAS-dif**  | Crosses above 0           | Crosses below 0           | -                | -               |
# | **MACDAS**      | Cross > MACDAS_Signal     | Cross < MACDAS_Signal     | -                | -               |
# | **MACDAS_Signal**| MACDAS confirmation      | MACDAS confirmation       | -                | -               |
# | **BB_BWidth**   | Expands sharply           | Contracts sharply         | -                | -               |
# | **BB_%B**       | Cross > 1.0               | Cross < 0.0               | > 1.0            | < 0.0           |
# | **YF%**         | Cross > 0                 | Cross < 0                 | -                | -               |
# | **MFI**         | Cross > 20                | Cross < 80                | > 80             | < 20            |
# | **RSI**         | Cross > 30                | Cross < 70                | > 70             | < 30            |
# | **ADX**         | Trend strength > 20       | Trend strength fades      | -                | -               |
# | **CCI**         | Cross > -100              | Cross < 100               | > 100            | < -100          |
# | **ROC**         | Cross > 0                 | Cross < 0                 | > 10             | < -10           |
# | **CMF**         | Crosses above 0           | Crosses below 0           | > 0.25           | < -0.25         |
# | **ATR**         | High volatility breakout  | Low volatility reversion  | -                | -               |
# | **FWMA**        | Cross > price             | Cross < price             | -                | -               |
# | **VWAP**        | Price > VWAP              | Price < VWAP              | -                | -               |
# | **Supertrend**  | Price crosses above       | Price crosses below       | -                | -               |
# | **st_way**      | Turns upward              | Turns downward            | -                | -               |
# | **kama**        | Cross > price             | Cross < price             | -                | -               |
# | **Tenkan**      | Cross > Kijun             | Cross < Kijun             | -                | -               |
# | **Kijun**       | Trend baseline            | Trend baseline            | -                | -               |
# | **Senkou_A**    | Cross > Senkou_B (bullish)| Cross < Senkou_B (bearish)| -                | -               |
# | **Senkou_B**    | Trend support/resistance  | Trend support/resistance  | -                | -               |
# | **Cloud_Position**| Price above cloud       | Price below cloud         | -                | -               |
# | **TK_Cross**    | Tenkan > Kijun (bullish)  | Tenkan < Kijun (bearish)  | -                | -               |
# | **CPrice**      | Trend confirmation        | Trend breakdown           | -                | -               |
# | **change**      | % change > 0              | % change < 0              | -                | -               |
#
# ---
#
# ### 📝 Footnotes: Indicator Explanations
#
# - **RSI**: Relative Strength Index — momentum oscillator indicating overbought/oversold.
# - **Stoch**: Stochastic Oscillator — compares close to recent high/low range.
# - **StochRSI_K / D**: Fast/slow lines of StochRSI; look for crossovers near extremes.
# - **MACD / MACDAS**: Measures momentum through moving average crossovers.
# - **BB_BWidth**: Bollinger Band Width — shows volatility expansion/contraction.
# - **BB_%B**: Shows price relative to Bollinger Bands.
# - **YF%**: Custom momentum/price-change metric (% from yesterday or a fixed base).
# - **MFI**: Money Flow Index — volume-weighted RSI.
# - **ADX**: Average Directional Index — trend strength (not direction).
# - **CCI**: Commodity Channel Index — deviation from mean price.
# - **ROC**: Rate of Change — measures speed of price movement.
# - **CMF**: Chaikin Money Flow — money flow volume over time (volume + price).
# - **ATR**: Average True Range — measures volatility.
# - **FWMA**: Forward Weighted MA — gives more weight to recent prices.
# - **VWAP**: Volume Weighted Average Price — intraday fair value tracker.
# - **Supertrend**: Trend-following indicator; filters noise.
# - **st_way**: Custom smoothed trend direction estimate.
# - **kama**: Kaufman Adaptive Moving Average — adjusts to market volatility.
# - **Ichimoku Indicators** (Tenkan, Kijun, Senkou A/B, TK_Cross, Cloud_Position): multi-component system identifying trend, momentum, and support/resistance.
# - **CPrice**: Current price, often used to confirm breakouts.
# - **change**: Percent change over selected time window.
#
# | Category                      | Strategy Name             | Key Tools/Indicators                              | Core Logic                                                                 |
# |------------------------------|---------------------------|----------------------------------------------------|----------------------------------------------------------------------------|
# | 📈 Technical Analysis        | Trend Following           | Moving Averages, MACD, ADX                         | Ride trends; buy in uptrend, sell in downtrend                            |
# |                              | Mean Reversion            | RSI, Bollinger Bands, Stochastic Oscillator        | Price reverts to the mean; buy oversold, sell overbought                  |
# |                              | Breakout Trading          | Price Levels, Volume, VWAP                         | Trade breakouts with volume confirmation                                  |
# |                              | Support/Resistance Bounce | S/R Zones, Candlestick Patterns                    | Trade bounces from key levels                                              |
# |                              | Momentum Trading          | ROC, RSI, MACD Histogram, Volume                   | Buy assets with strong price & volume momentum                            |
# | 🧠 Algorithmic / Quant       | Statistical Arbitrage     | Cointegration, Spread, Z-Score                     | Trade mean-reverting pairs; exploit pricing inefficiencies                |
# |                              | ML-Based Trading          | XGBoost, LSTM, Random Forest                       | Predict price movement with supervised learning                           |
# | 🕒 By Timeframe              | Scalping                  | Level 2, VWAP, Order Book                          | Rapid in/out trades; small price moves                                    |
# |                              | Day Trading               | VWAP, News, 1–15m charts                           | Intraday trading; no overnight positions                                  |
# |                              | Swing Trading             | Trendlines, RSI, Fibonacci                         | Catch short-term swings (days/weeks)                                      |
# |                              | Position Trading          | Weekly/Monthly Charts, Macro Indicators            | Ride long-term trends (weeks/months)                                      |
# | 🔍 Fundamental Analysis      | Earnings Momentum         | EPS Surprise, Guidance, Analyst Ratings           | Buy on strong earnings beats and bullish guidance                         |
# |                              | Value Investing           | P/E, P/B, DCF, ROE                                 | Buy undervalued companies with solid fundamentals                         |
# |                              | Event-Driven Trading      | News, FDA, M&A Events, Earnings Dates             | Trade based on major catalysts                                            |
# | 📊 Rule-Based Examples       | RSI + 200 MA              | RSI, 200-day Moving Average                        | Buy if RSI < 30 and price > 200 MA                                        |
# |                              | MACD Histogram Reversal   | MACD Histogram                                     | Buy on negative → positive crossover, sell on reversal                    |
# |                              | Supertrend + ADX Filter   | Supertrend, ADX                                    | Buy if Supertrend is green and ADX > 20                                   |

# %%
import yfinance as yf, pandas as pd, matplotlib.pyplot as plt, pandas_ta as ta, numpy as np
import os, math, time, warnings
import Classic_Analysis
from Classic_Analysis import endeks, sectors, portfolio, nasdaq, Coin, bist, bist100, global_Markets,US_stocks
from datetime import datetime, timedelta
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)        # Don't wrap columns
pd.set_option('display.max_colwidth', None) # Show full content of each column
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
Classic_Analysis.classic_analysis(US_stocks)
# Out:
# 150/712 Downloaded GSK dataaa
# $NSC: possibly delisted; no price data found  (period=1y)
# No historical data for NSC, skipping...
# 711/712 Downloaded WSO-B data
# Download process is done!
# Stock Market Data Processing is Done!

# %%
df2 = pd.read_csv(f"CSVs/Results last.csv")
df2
# Out:
#      Unnamed: 0 symbol  priceToBook    CPrice  targetHighPrice  \
# 0             0   NVDA        50.15    172.41           250.00
# 1             1    WBD         0.93     12.75            24.00
# 2             2   TSLA        14.22    329.65           500.00
# 3             3     NU         7.30     13.02            18.90
# 4             4      F         0.99     11.16            16.00
# ..          ...    ...          ...       ...              ...
# 706         706  MKC-V         3.43     71.56              NaN
# 707         707    NVR         5.53   7422.83          8000.00
# 708         708   BBDO         0.15      2.43              NaN
# 709         709  BRK-A         1.56 710978.00        887099.00
# 710         710  WSO-B         6.18    434.48              NaN
#
#      targetLowPrice  targetMeanPrice  targetMedianPrice  bookValue      open  \
# 0            100.00           173.92             175.00       3.44    173.73
# 1              9.00            13.92              13.50      13.68     12.96
# 2            115.00           306.07             303.00      23.18    322.00
# 3              9.00            14.62              15.00       1.78     13.98
# 4              8.00            10.37              10.00      11.22     11.17
# ..              ...              ...                ...        ...       ...
# 706             NaN              NaN                NaN      20.87     72.74
# 707         7200.00          7700.00            7900.00    1343.02   7488.97
# 708             NaN              NaN                NaN      16.12      2.48
# 709       727000.00        769899.75          732750.00  454913.60 711222.00
# 710             NaN              NaN                NaN      70.34    437.48
#
#        dayLow   dayHigh recommendationKey  fiftyTwoWeekLow  fiftyTwoWeekHigh  \
# 0      171.26    174.24        strong_buy            86.62            174.25
# 1       12.57     12.99               buy             6.64             13.04
# 2      321.42    330.90              hold           182.00            488.54
# 3       12.99     13.96               buy             9.01             16.14
# 4       11.05     11.24              hold             8.44             14.18
# ..        ...       ...               ...              ...               ...
# 706     70.96     72.66              none            70.08             85.50
# 707   7371.85   7488.97              hold          6562.85           9964.77
# 708      2.43      2.52              none             1.71              2.88
# 709 709940.00 717455.60               buy        609579.00         812855.00
# 710    437.48    437.48              none           437.48            535.00
#
#       RSI   ADX     CCI    ROC     ATR           OBV  CMF            AD   MFI  \
# 0   78.29 51.47  131.01  12.47    3.88 3253676600.00 0.26 4728381148.98 66.60
# 1   76.15 52.60  169.74  16.54    0.43 1188807000.00 0.09  112665953.97 75.45
# 2   55.85 15.48   61.36   9.62   13.84 1028592600.00 0.04 1167196418.30 62.31
# 3   49.07 25.90    6.71  -4.55    0.50  691719400.00 0.11  750467609.88 68.86
# 4   50.34 23.94  -17.86  -1.67    0.27  370892500.00 0.16 -113083049.66 52.88
# ..    ...   ...     ...    ...     ...           ...  ...           ...   ...
# 706 44.08 12.17  -72.66  -6.88    1.50      60400.00 0.04     170593.47  5.17
# 707 50.36 14.96  -12.29  -3.20  173.00    -346400.00 0.13    -159317.87 48.54
# 708 39.62 16.50 -160.56 -14.44    0.10     132300.00 0.13    2742012.11 36.19
# 709 38.10 28.15  -67.56  -3.02 8993.11       9100.00 0.06      10533.31 41.86
# 710 31.21 63.65   -8.39   0.69    0.76       2400.00 0.00       7831.37   NaN
#
#         MACD  MACD_signal  MACD_Hist  MACDAS  MACDAS_Signal  BB_Middle  \
# 0       7.98         7.32       0.66    0.66           0.54     159.63
# 1       0.63         0.52       0.11    0.11           0.06      11.48
# 2      -0.39        -2.16       1.77    1.77          -0.49     317.35
# 3       0.25         0.28      -0.03   -0.03           0.00      13.31
# 4       0.23         0.30      -0.07   -0.07           0.01      11.28
# ..       ...          ...        ...     ...            ...        ...
# 706    -0.65        -0.38      -0.27   -0.27          -0.25      73.50
# 707    55.85        83.90     -28.05  -28.05          -1.47    7465.79
# 708    -0.02         0.01      -0.03   -0.03          -0.02       2.62
# 709 -8991.44     -8830.19    -161.24 -161.24        -343.79  721453.50
# 710    -4.08        -5.24       1.15    1.15           0.64     438.04
#
#      BB_Upper  BB_Lower  BB_%B  BB_BWidth      FWMA      VWAP      kama  \
# 0      176.42    142.84   0.88      21.04    170.94    172.64    165.56
# 1       12.78     10.18   0.99      22.66     12.53     12.77     11.72
# 2      344.62    290.09   0.73      17.18    321.67    327.32    323.05
# 3       14.22     12.39   0.34      13.74     13.43     13.33     13.09
# 4       12.25     10.30   0.44      17.28     11.30     11.15     11.40
# ..        ...       ...    ...        ...       ...       ...       ...
# 706     77.27     69.73   0.24      10.26     71.75     71.75     73.60
# 707   7820.28   7111.29   0.44       9.50   7437.74   7427.88   7409.04
# 708      2.80      2.43  -0.01      13.80      2.50      2.46      2.60
# 709 741324.36 701582.64   0.24       5.51 710172.59 712806.33 726557.86
# 710    448.50    427.58   0.47       4.77    436.77       NaN    436.38
#
#       EMA_200  Supertrend  st_way  Stoch_K  Stoch_D  StochRSI_K  StochRSI_D  \
# 0      133.78      161.24       1    93.96    92.79       96.21       94.84
# 1        9.71       11.51       1    91.54    90.92       95.87       97.09
# 2      304.53      342.96      -1    83.46    67.15       97.17       87.32
# 3       12.71       12.60       1    66.76    70.61       53.76       58.50
# 4       10.26       11.09       1    41.50    56.24        0.30       16.75
# ..        ...         ...     ...      ...      ...         ...         ...
# 706     75.64       74.80      -1    19.01    13.66       24.33       13.34
# 707   7954.20     7176.39       1    31.13    34.45       19.05       16.24
# 708      2.24        2.39       1     8.13    12.20        2.48        4.01
# 709 720277.80   732296.76      -1    20.36    13.02       37.99       22.21
# 710    471.47      435.61       1    74.71    41.38      100.00       66.67
#
#        Tenkan     Kijun  Senkou_A  Senkou_B  Chikou  \
# 0      138.95    127.90    103.67    114.03     NaN
# 1       10.11      9.58      8.88      9.71     NaN
# 2      320.46    319.35    258.45    290.79     NaN
# 3       11.99     12.72     11.28     11.34     NaN
# 4       10.26     10.36      9.55      9.28     NaN
# ..        ...       ...       ...       ...     ...
# 706     72.82     73.18     76.28     77.63     NaN
# 707   7172.64   7254.06   7125.36   7153.32     NaN
# 708      2.56      2.40      2.11      2.03     NaN
# 709 744275.00 755532.00 772188.25 754186.00     NaN
# 710    446.91    457.47    473.88    474.76     NaN
#
#                            time   YF%  MACDAS-dif  change  BB_Pot  BB_Opt  \
# 0    2025-07-20 17:07:35.159777 97.90        0.13   -0.76    2.33  -17.15
# 1    2025-07-20 17:07:35.159777 95.47        0.04   -1.58    0.27  -20.14
# 2    2025-07-20 17:07:35.159777 48.17        2.26    2.38    4.54  -12.00
# 3    2025-07-20 17:07:35.159777 56.20       -0.03   -6.87    9.23   -4.82
# 4    2025-07-20 17:07:35.159777 47.39       -0.09   -0.09    9.78   -7.68
# ..                          ...   ...         ...     ...     ...     ...
# 706  2025-07-20 17:07:35.159777  9.60       -0.02   -1.62    7.98   -2.55
# 707  2025-07-20 17:07:35.159777 25.28      -26.59   -0.88    5.35   -4.20
# 708  2025-07-20 17:07:35.159777 61.54       -0.01   -2.02   15.04    0.19
# 709  2025-07-20 17:07:35.159777 49.88      182.55   -0.03    4.27   -1.32
# 710  2025-07-20 17:07:35.159777 -3.08        0.52   -0.69    3.23   -1.59
#
#      TrendWay Cloud_Position TK_Cross
# 0       upper    Above_Cloud  Bullish
# 1       upper    Above_Cloud  Bullish
# 2    no-trend    Above_Cloud  Bullish
# 3       lower    Above_Cloud  Bearish
# 4       lower    Above_Cloud  Bearish
# ..        ...            ...      ...
# 706  no-trend    Below_Cloud  Bearish
# 707  no-trend    Above_Cloud  Bearish
# 708  no-trend    Above_Cloud  Bullish
# 709     lower    Below_Cloud  Bearish
# 710     upper    Below_Cloud  Bearish
#
# [711 rows x 58 columns]

# %%
test = df2.copy()
#test = test[test["BB_%B"] < 0.2]
test = test[test["FWMA"] < test["CPrice"]]
test
# Out:
#      Unnamed: 0 symbol  priceToBook    CPrice  targetHighPrice  \
# 0             0   NVDA        50.15    172.41           250.00
# 1             1    WBD         0.93     12.75            24.00
# 2             2   TSLA        14.22    329.65           500.00
# 5             5   INTC         1.01     23.10            28.30
# 7             7    BAC         1.27     47.32            57.00
# ..          ...    ...          ...       ...              ...
# 697         697   BKNG       -30.51   5702.90          6255.00
# 701         701    AZO       -15.63   3713.93          4850.00
# 702         702     UI        63.86    460.40           440.00
# 704         704    MKL         1.56   2031.80          2000.00
# 709         709  BRK-A         1.56 710978.00        887099.00
#
#      targetLowPrice  targetMeanPrice  targetMedianPrice  bookValue      open  \
# 0            100.00           173.92             175.00       3.44    173.73
# 1              9.00            13.92              13.50      13.68     12.96
# 2            115.00           306.07             303.00      23.18    322.00
# 5             14.00            21.29              21.00      22.87     23.20
# 7             43.00            50.54              51.00      37.13     47.01
# ..              ...              ...                ...        ...       ...
# 697         4440.00          5583.99            5700.00    -186.92   5749.59
# 701         2896.05          4079.96            4145.00    -237.65   3665.22
# 702          247.00           343.50             343.50       7.21    448.43
# 704         1630.00          1879.20            1930.00    1303.40   2020.40
# 709       727000.00        769899.75          732750.00  454913.60 711222.00
#
#        dayLow   dayHigh recommendationKey  fiftyTwoWeekLow  fiftyTwoWeekHigh  \
# 0      171.26    174.24        strong_buy            86.62            174.25
# 1       12.57     12.99               buy             6.64             13.04
# 2      321.42    330.90              hold           182.00            488.54
# 5       22.90     23.59              hold            17.67             33.41
# 7       46.90     47.38               buy            33.07             49.31
# ..        ...       ...               ...              ...               ...
# 697   5684.00   5749.59               buy          3180.00           5839.41
# 701   3650.00   3715.93               buy          2894.02           3916.81
# 702    444.00    461.72              none           156.94            469.98
# 704   2018.37   2032.48              none          1491.03           2063.68
# 709 709940.00 717455.60               buy        609579.00         812855.00
#
#       RSI   ADX    CCI   ROC     ATR           OBV   CMF            AD   MFI  \
# 0   78.29 51.47 131.01 12.47    3.88 3253676600.00  0.26 4728381148.98 66.60
# 1   76.15 52.60 169.74 16.54    0.43 1188807000.00  0.09  112665953.97 75.45
# 2   55.85 15.48  61.36  9.62   13.84 1028592600.00  0.04 1167196418.30 62.31
# 5   56.67 31.77  69.09  1.09    0.82 -830150500.00 -0.03 -840880735.79 55.94
# 7   58.01 21.78  11.75 -1.72    0.93  419674100.00  0.16  170544363.41 46.21
# ..    ...   ...    ...   ...     ...           ...   ...           ...   ...
# 697 57.70 28.47  44.06 -0.49  100.65    5423100.00  0.19    3988203.13 47.04
# 701 51.64 14.13  17.20 -0.13   75.15    3295900.00  0.31    2524502.05 57.93
# 702 73.57 16.16 254.03 12.56   13.76    3514500.00  0.32    3132179.17 57.88
# 704 61.54 14.39 264.30  1.88   32.31    1580400.00  0.21     759184.40 59.52
# 709 38.10 28.15 -67.56 -3.02 8993.11       9100.00  0.06      10533.31 41.86
#
#         MACD  MACD_signal  MACD_Hist  MACDAS  MACDAS_Signal  BB_Middle  \
# 0       7.98         7.32       0.66    0.66           0.54     159.63
# 1       0.63         0.52       0.11    0.11           0.06      11.48
# 2      -0.39        -2.16       1.77    1.77          -0.49     317.35
# 5       0.50         0.55      -0.05   -0.05           0.04      22.65
# 7       0.54         0.76      -0.23   -0.23          -0.18      47.15
# ..       ...          ...        ...     ...            ...        ...
# 697    76.44        90.98     -14.55  -14.55          -4.57    5647.61
# 701     5.92         6.47      -0.55   -0.55           5.66    3683.67
# 702    11.57         7.15       4.42    4.42           1.38     409.54
# 704    19.52        19.10       0.42    0.42          -1.29    1991.13
# 709 -8991.44     -8830.19    -161.24 -161.24        -343.79  721453.50
#
#      BB_Upper  BB_Lower  BB_%B  BB_BWidth      FWMA      VWAP      kama  \
# 0      176.42    142.84   0.88      21.04    170.94    172.64    165.56
# 1       12.78     10.18   0.99      22.66     12.53     12.77     11.72
# 2      344.62    290.09   0.73      17.18    321.67    327.32    323.05
# 5       24.07     21.22   0.66      12.60     22.99     23.20     21.87
# 7       48.90     45.39   0.55       7.44     46.92     47.20     47.33
# ..        ...       ...    ...        ...       ...       ...       ...
# 697   5920.40   5374.81   0.60       9.66   5694.11   5712.16   5628.18
# 701   3840.02   3527.31   0.60       8.49   3696.96   3693.29   3669.86
# 702    447.34    371.74   1.17      18.46    439.50    455.37    417.93
# 704   2026.07   1956.18   1.08       3.51   2013.69   2026.59   1948.55
# 709 741324.36 701582.64   0.24       5.51 710172.59 712806.33 726557.86
#
#       EMA_200  Supertrend  st_way  Stoch_K  Stoch_D  StochRSI_K  StochRSI_D  \
# 0      133.78      161.24       1    93.96    92.79       96.21       94.84
# 1        9.71       11.51       1    91.54    90.92       95.87       97.09
# 2      304.53      342.96      -1    83.46    67.15       97.17       87.32
# 5       21.93       21.13       1    53.31    54.15       15.37       17.75
# 7       43.19       48.52      -1    41.40    28.56       18.60       10.10
# ..        ...         ...     ...      ...      ...         ...         ...
# 697   4899.75     5436.03       1    37.92    48.85        8.27        7.65
# 701   3459.54     3536.53       1    59.10    66.52       31.73       46.15
# 702    334.42      410.98       1    94.24    82.34       90.68       70.34
# 704   1802.66     1929.62       1    88.05    75.35       67.05       44.54
# 709 720277.80   732296.76      -1    20.36    13.02       37.99       22.21
#
#        Tenkan     Kijun  Senkou_A  Senkou_B  Chikou  \
# 0      138.95    127.90    103.67    114.03     NaN
# 1       10.11      9.58      8.88      9.71     NaN
# 2      320.46    319.35    258.45    290.79     NaN
# 5       20.88     21.09     20.54     22.04     NaN
# 7       44.25     42.86     38.47     39.63     NaN
# ..        ...       ...       ...       ...     ...
# 697   5528.94   5330.33   4743.49   4675.64     NaN
# 701   3706.16   3737.51   3668.66   3638.16     NaN
# 702    401.99    400.47    307.55    299.98     NaN
# 704   1933.39   1902.18   1781.87   1787.34     NaN
# 709 744275.00 755532.00 772188.25 754186.00     NaN
#
#                            time   YF%  MACDAS-dif  change  BB_Pot  BB_Opt  \
# 0    2025-07-20 17:07:35.159777 97.90        0.13   -0.76    2.33  -17.15
# 1    2025-07-20 17:07:35.159777 95.47        0.04   -1.58    0.27  -20.14
# 2    2025-07-20 17:07:35.159777 48.17        2.26    2.38    4.54  -12.00
# 5    2025-07-20 17:07:35.159777 34.50       -0.09   -0.43    4.21   -8.14
# 7    2025-07-20 17:07:35.159777 87.75       -0.05    0.66    3.34   -4.07
# ..                          ...   ...         ...     ...     ...     ...
# 697  2025-07-20 17:07:35.159777 94.87       -9.97   -0.81    3.81   -5.75
# 701  2025-07-20 17:07:35.159777 80.16       -6.21    1.33    3.40   -5.02
# 702  2025-07-20 17:07:35.159777 96.94        3.04    2.67   -2.84  -19.26
# 704  2025-07-20 17:07:35.159777 94.43        1.71    0.56   -0.28   -3.72
# 709  2025-07-20 17:07:35.159777 49.88      182.55   -0.03    4.27   -1.32
#
#      TrendWay Cloud_Position TK_Cross
# 0       upper    Above_Cloud  Bullish
# 1       upper    Above_Cloud  Bullish
# 2    no-trend    Above_Cloud  Bullish
# 5       upper    Above_Cloud  Bearish
# 7       lower    Above_Cloud  Bullish
# ..        ...            ...      ...
# 697     lower    Above_Cloud  Bullish
# 701  no-trend    Above_Cloud  Bearish
# 702  no-trend    Above_Cloud  Bullish
# 704  no-trend    Above_Cloud  Bullish
# 709     lower    Below_Cloud  Bearish
#
# [394 rows x 58 columns]
