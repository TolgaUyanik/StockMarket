# %% [markdown]
# # US Stock Market
#
# ## 🚨 QUICK SIGNAL REFERENCE
#
# | Indicator       | Buy Signal                | Sell Signal               | Overbought       | Oversold        |
# |-----------------|---------------------------|---------------------------|------------------|-----------------|
# | **RSI**         | Cross > 30                | Cross < 70                | > 70             | < 30            |
# | **Stoch**       | %K > %D in < 20           | %K < %D in > 80           | > 80             | < 20            |
# | **StochRSI**    | Cross > 20                | Cross < 80                | > 80             | < 20            |
# | **StochRSI_K**  | Cross > StochRSI_D        | Cross < StochRSI_D        | > 80             | < 20            |
# | **StochRSI_D**  | Smoother confirmation     | Smoother confirmation     | > 80             | < 20            |
# | **MACD**        | Line > Signal             | Line < Signal             | -                | -               |
# | **MACDAS-dif**  | Crosses above 0           | Crosses below 0           | -                | -               |
# | **MACDAS**      | Cross > MACDAS_Signal     | Cross < MACDAS_Signal     | -                | -               |
# | **MACDAS_Signal**| MACDAS confirmation      | MACDAS confirmation       | -                | -               |
# | **BB_BWidth**   | Expands sharply           | Contracts sharply         | -                | -               |
# | **BB_%B**       | Cross > 1.0               | Cross < 0.0               | > 1.0            | < 0.0           |
# | **YF%**         | Cross > 0                 | Cross < 0                 | -                | -               |
# | **MFI**         | Cross > 20                | Cross < 80                | > 80             | < 20            |
# | **RSI**         | Cross > 30                | Cross < 70                | > 70             | < 30            |
# | **ADX**         | Trend strength > 20       | Trend strength fades      | -                | -               |
# | **CCI**         | Cross > -100              | Cross < 100               | > 100            | < -100          |
# | **ROC**         | Cross > 0                 | Cross < 0                 | > 10             | < -10           |
# | **CMF**         | Crosses above 0           | Crosses below 0           | > 0.25           | < -0.25         |
# | **ATR**         | High volatility breakout  | Low volatility reversion  | -                | -               |
# | **FWMA**        | Cross > price             | Cross < price             | -                | -               |
# | **VWAP**        | Price > VWAP              | Price < VWAP              | -                | -               |
# | **Supertrend**  | Price crosses above       | Price crosses below       | -                | -               |
# | **st_way**      | Turns upward              | Turns downward            | -                | -               |
# | **kama**        | Cross > price             | Cross < price             | -                | -               |
# | **Tenkan**      | Cross > Kijun             | Cross < Kijun             | -                | -               |
# | **Kijun**       | Trend baseline            | Trend baseline            | -                | -               |
# | **Senkou_A**    | Cross > Senkou_B (bullish)| Cross < Senkou_B (bearish)| -                | -               |
# | **Senkou_B**    | Trend support/resistance  | Trend support/resistance  | -                | -               |
# | **Cloud_Position**| Price above cloud       | Price below cloud         | -                | -               |
# | **TK_Cross**    | Tenkan > Kijun (bullish)  | Tenkan < Kijun (bearish)  | -                | -               |
# | **CPrice**      | Trend confirmation        | Trend breakdown           | -                | -               |
# | **change**      | % change > 0              | % change < 0              | -                | -               |
#
# ---
#
# ### 📝 Footnotes: Indicator Explanations
#
# - **RSI**: Relative Strength Index — momentum oscillator indicating overbought/oversold.
# - **Stoch**: Stochastic Oscillator — compares close to recent high/low range.
# - **StochRSI_K / D**: Fast/slow lines of StochRSI; look for crossovers near extremes.
# - **MACD / MACDAS**: Measures momentum through moving average crossovers.
# - **BB_BWidth**: Bollinger Band Width — shows volatility expansion/contraction.
# - **BB_%B**: Shows price relative to Bollinger Bands.
# - **YF%**: Custom momentum/price-change metric (% from yesterday or a fixed base).
# - **MFI**: Money Flow Index — volume-weighted RSI.
# - **ADX**: Average Directional Index — trend strength (not direction).
# - **CCI**: Commodity Channel Index — deviation from mean price.
# - **ROC**: Rate of Change — measures speed of price movement.
# - **CMF**: Chaikin Money Flow — money flow volume over time (volume + price).
# - **ATR**: Average True Range — measures volatility.
# - **FWMA**: Forward Weighted MA — gives more weight to recent prices.
# - **VWAP**: Volume Weighted Average Price — intraday fair value tracker.
# - **Supertrend**: Trend-following indicator; filters noise.
# - **st_way**: Custom smoothed trend direction estimate.
# - **kama**: Kaufman Adaptive Moving Average — adjusts to market volatility.
# - **Ichimoku Indicators** (Tenkan, Kijun, Senkou A/B, TK_Cross, Cloud_Position): multi-component system identifying trend, momentum, and support/resistance.
# - **CPrice**: Current price, often used to confirm breakouts.
# - **change**: Percent change over selected time window.
#
# | Category                      | Strategy Name             | Key Tools/Indicators                              | Core Logic                                                                 |
# |------------------------------|---------------------------|----------------------------------------------------|----------------------------------------------------------------------------|
# | 📈 Technical Analysis        | Trend Following           | Moving Averages, MACD, ADX                         | Ride trends; buy in uptrend, sell in downtrend                            |
# |                              | Mean Reversion            | RSI, Bollinger Bands, Stochastic Oscillator        | Price reverts to the mean; buy oversold, sell overbought                  |
# |                              | Breakout Trading          | Price Levels, Volume, VWAP                         | Trade breakouts with volume confirmation                                  |
# |                              | Support/Resistance Bounce | S/R Zones, Candlestick Patterns                    | Trade bounces from key levels                                              |
# |                              | Momentum Trading          | ROC, RSI, MACD Histogram, Volume                   | Buy assets with strong price & volume momentum                            |
# | 🧠 Algorithmic / Quant       | Statistical Arbitrage     | Cointegration, Spread, Z-Score                     | Trade mean-reverting pairs; exploit pricing inefficiencies                |
# |                              | ML-Based Trading          | XGBoost, LSTM, Random Forest                       | Predict price movement with supervised learning                           |
# | 🕒 By Timeframe              | Scalping                  | Level 2, VWAP, Order Book                          | Rapid in/out trades; small price moves                                    |
# |                              | Day Trading               | VWAP, News, 1–15m charts                           | Intraday trading; no overnight positions                                  |
# |                              | Swing Trading             | Trendlines, RSI, Fibonacci                         | Catch short-term swings (days/weeks)                                      |
# |                              | Position Trading          | Weekly/Monthly Charts, Macro Indicators            | Ride long-term trends (weeks/months)                                      |
# | 🔍 Fundamental Analysis      | Earnings Momentum         | EPS Surprise, Guidance, Analyst Ratings           | Buy on strong earnings beats and bullish guidance                         |
# |                              | Value Investing           | P/E, P/B, DCF, ROE                                 | Buy undervalued companies with solid fundamentals                         |
# |                              | Event-Driven Trading      | News, FDA, M&A Events, Earnings Dates             | Trade based on major catalysts                                            |
# | 📊 Rule-Based Examples       | RSI + 200 MA              | RSI, 200-day Moving Average                        | Buy if RSI < 30 and price > 200 MA                                        |
# |                              | MACD Histogram Reversal   | MACD Histogram                                     | Buy on negative → positive crossover, sell on reversal                    |
# |                              | Supertrend + ADX Filter   | Supertrend, ADX                                    | Buy if Supertrend is green and ADX > 20                                   |

# %%
import yfinance as yf, pandas as pd, matplotlib.pyplot as plt, pandas_ta as ta, numpy as np
import os, math, time, warnings
import Classic_Analysis
from Classic_Analysis import endeks, sectors, portfolio, nasdaq, Coin, bist, bist100, global_Markets,US_stocks
from datetime import datetime, timedelta
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)        # Don't wrap columns
pd.set_option('display.max_colwidth', None) # Show full content of each column
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
Classic_Analysis.classic_analysis(US_stocks)

# %%
df2 = pd.read_csv(f"CSVs/Results last.csv")
df2

# %%
test = df2.copy()
#test = test[test["BB_%B"] < 0.2]
test = test[test["FWMA"] < test["CPrice"]]
test

# %%
import pandas as pd
import pandas_ta as ta
import yfinance as yf

# Example: Download 1 year of daily data for AAPL
df = yf.download("AAPL", period="1y", interval="1d")

# yfinance already returns a DatetimeIndex, but if your df had a 'datetime' column:
# df.set_index(pd.DatetimeIndex(df["datetime"]), inplace=True)

# Run all technical indicators
df.ta.strategy(verbose=True)

# Display the first few rows
print(df.head())
# Out:
# C:\Users\Tolga\AppData\Local\Temp\ipykernel_9960\2486478462.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("AAPL", period="1y", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# [+] Strategy: All
# [i] Indicator arguments: {'append': True}
# [i] Excluded[12]: above, above_value, below, below_value, cross, cross_value, long_run, short_run, td_seq, tsignals, vp, xsignals
# [i] Multiprocessing 131 indicators with 3 chunks and 12/12 cpus.
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 12
#       6 df = yf.download("AAPL", period="1y", interval="1d")
#       8 # yfinance already returns a DatetimeIndex, but if your df had a 'datetime' column:
#       9 # df.set_index(pd.DatetimeIndex(df["datetime"]), inplace=True)
#      10
#      11 # Run all technical indicators
# ---> 12 df.ta.strategy(verbose=True)
#      14 # Display the first few rows
#      15 print(df.head())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas_ta\core.py:760, in AnalysisIndicators.strategy(self, *args, **kwargs)
#     757             return
#     759         pool.close()
# --> 760         pool.join()
#     761         self._last_run = get_time(self.exchange, to_string=True)
#     763 else:
#     764     # Without multiprocessing:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\pool.py:665, in Pool.join(self)
#     663 elif self._state not in (CLOSE, TERMINATE):
#     664     raise ValueError("In unknown state")
# --> 665 self._worker_handler.join()
#     666 self._task_handler.join()
#     667 self._result_handler.join()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:1119, in Thread.join(self, timeout)
#    1116     raise RuntimeError("cannot join current thread")
#    1118 if timeout is None:
# -> 1119     self._wait_for_tstate_lock()
#    1120 else:
#    1121     # the behavior of a negative timeout isn't documented, but
#    1122     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1123     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:1139, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1136     return
#    1138 try:
# -> 1139     if lock.acquire(block, timeout):
#    1140         lock.release()
#    1141         self._stop()
#
# KeyboardInterrupt:

# %%
import pandas_ta as ta
import yfinance as yf

# Download data
df = yf.download("AAPL", period="1y", interval="1d")

# Flatten multi-index columns
df.columns = df.columns.get_level_values(0)

# Rename columns to match pandas_ta expectations
df.columns = ["Open", "High", "Low", "Close", "Volume"]

print("Original DataFrame:")
print(df.head())

# Add commonly used indicators individually (these should work fine)
print("Adding indicators...")

# Moving Averages
df.ta.sma(length=20, append=True)
df.ta.ema(length=20, append=True)

# RSI
df.ta.rsi(length=14, append=True)

# MACD
df.ta.macd(append=True)

# Bollinger Bands
df.ta.bbands(length=20, append=True)

# Volume indicators
df.ta.ad(append=True)  # Accumulation/Distribution
df.ta.obv(append=True)  # On Balance Volume

# Momentum indicators
df.ta.stoch(append=True)  # Stochastic
df.ta.willr(append=True)  # Williams %R

# Volatility
df.ta.atr(length=14, append=True)  # Average True Range

print(f"Final DataFrame shape: {df.shape}")
print("New columns added:")
for col in df.columns:
    if col not in ["Open", "High", "Low", "Close", "Volume"]:
        print(f"  - {col}")

print("\nDataFrame with indicators:")
print(df.tail())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Original DataFrame:
#              Open   High    Low  Close    Volume
# Date
# 2024-08-09 215.23 215.77 210.98 211.11  42201600
# 2024-08-12 216.77 218.74 214.84 215.31  38028100
# 2024-08-13 220.49 221.11 218.24 218.24  44155300
# 2024-08-14 220.94 222.25 218.93 219.80  41960600
# 2024-08-15 223.93 224.56 221.98 223.81  46414000
# Adding indicators...
# Final DataFrame shape: (250, 22)
# New columns added:
#   - SMA_20
#   - EMA_20
#   - RSI_14
#   - MACD_12_26_9
#   - MACDh_12_26_9
#   - MACDs_12_26_9
#   - BBL_20_2.0
#   - BBM_20_2.0
#   - BBU_20_2.0
#   - BBB_20_2.0
#   - BBP_20_2.0
#   - AD
#   - OBV
#   - STOCHk_14_3_3
#   - STOCHd_14_3_3
#   - WILLR_14
#   - ATRr_14
#
# DataFrame with indicators:
#              Open   High    Low  Close     Volume  SMA_20  EMA_20  RSI_14  \
# Date
# 2025-08-04 203.35 207.88 201.68 204.51   75109300  211.22  210.17   39.67
# 2025-08-05 202.92 205.34 202.16 203.40   44155100  210.89  209.52   37.93
# 2025-08-06 213.25 215.38 205.59 205.63  108483100  210.69  209.15   43.32
# 2025-08-07 220.03 220.85 216.58 218.88   90224800  211.11  210.08   63.56
# 2025-08-08 229.35 231.00 219.25 220.83  113696100  211.62  211.10   65.51
#
#             MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9  BBL_20_2.0  \
# Date
# 2025-08-04          0.99          -0.99           1.97      206.32
# 2025-08-05          0.34          -1.31           1.65      204.93
# 2025-08-06          0.01          -1.31           1.32      204.33
# 2025-08-07          0.81          -0.41           1.22      203.81
# 2025-08-08          1.58           0.29           1.29      203.20
#
#             BBM_20_2.0  BBU_20_2.0  BBB_20_2.0  BBP_20_2.0            AD  \
# Date
# 2025-08-04      211.22      216.12        4.64       -0.19 -776884377.88
# 2025-08-05      210.89      216.84        5.65       -0.13 -786604245.86
# 2025-08-06      210.69      217.06        6.04        0.10 -894200676.36
# 2025-08-07      211.11      218.40        6.91        1.03 -887227767.84
# 2025-08-08      211.62      220.05        7.96        1.05 -970346838.70
#
#                      OBV  STOCHk_14_3_3  STOCHd_14_3_3  WILLR_14  ATRr_14
# Date
# 2025-08-04 1124218600.00          34.04          42.78    -78.92     4.87
# 2025-08-05 1080063500.00          33.33          37.34    -86.69     4.75
# 2025-08-06 1188546600.00          21.10          29.49    -71.08     5.26
# 2025-08-07 1278771400.00          44.02          32.82    -10.18     5.98
# 2025-08-08 1392467500.00          61.42          42.18    -34.47     6.41

# %%
df = yf.download("AAPL", period="1y", interval="1d")

# Flatten multi-index columns (Price, Ticker -> single name)
df.columns = df.columns.get_level_values(0)

# Rename columns to match pandas_ta expectations
df.columns = ["Close", "High", "Low", "Open", "Volume"]

# Convert index to datetime and name it 'datetime'
df.index = pd.to_datetime(df.index)
#df.index.name = "datetime"
df["datetime"] = df.index
df
# Out:
# C:\Users\Tolga\AppData\Local\Temp\ipykernel_9960\924010219.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("AAPL", period="1y", interval="1d")
# [*********************100%***********************]  1 of 1 completed
#                  Close        High         Low        Open     Volume  \
# Date
# 2024-08-09  215.233429  215.770909  210.983301  211.112701   42201600
# 2024-08-12  216.768036  218.741096  214.844804  215.313158   38028100
# 2024-08-13  220.494934  221.112757  218.242841  218.242841   44155300
# 2024-08-14  220.943359  222.248768  218.930431  219.797394   41960600
# 2024-08-15  223.932846  224.560644  221.979705  223.813271   46414000
# ...                ...         ...         ...         ...        ...
# 2025-08-04  203.350006  207.880005  201.679993  204.509995   75109300
# 2025-08-05  202.919998  205.339996  202.160004  203.399994   44155100
# 2025-08-06  213.250000  215.380005  205.589996  205.630005  108483100
# 2025-08-07  220.029999  220.850006  216.580002  218.880005   90224800
# 2025-08-08  229.350006  231.000000  219.250000  220.830002  113696100
#
#              datetime
# Date
# 2024-08-09 2024-08-09
# 2024-08-12 2024-08-12
# 2024-08-13 2024-08-13
# 2024-08-14 2024-08-14
# 2024-08-15 2024-08-15
# ...               ...
# 2025-08-04 2025-08-04
# 2025-08-05 2025-08-05
# 2025-08-06 2025-08-06
# 2025-08-07 2025-08-07
# 2025-08-08 2025-08-08
#
# [250 rows x 6 columns]

# %%
import pandas as pd
import pandas_ta as ta

# Example: read your CSV with multi-level headers
#df = pd.read_csv("yourfile.csv", header=[0, 1], index_col=0)
df = yf.download("AAPL", period="1y", interval="1d")

# Flatten multi-index columns (Price, Ticker -> single name)
df.columns = df.columns.get_level_values(0)

# Rename columns to match pandas_ta expectations
df.columns = ["Close", "High", "Low", "Open", "Volume"]

# Convert index to datetime and name it 'datetime'
df.index = pd.to_datetime(df.index)
df.index.name = "datetime"

# Now your original code will work:
df.ta.strategy()
df.ta.strategy("all")
df.ta.strategy(ta.AllStrategy)
df.ta.strategy(verbose=True)
df.ta.strategy(timed=True)
df.ta.cores = 4
df.ta.strategy(exclude=["bop", "mom", "percent_return", "wcp", "pvi"], verbose=True)
df.ta.strategy(fast=10, slow=50, verbose=True)

print(df.columns)  # Sanity check
# Out:
# C:\Users\Tolga\AppData\Local\Temp\ipykernel_9960\4221195706.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("AAPL", period="1y", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# 63it [00:06,  9.32it/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Tolga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas_ta\core.py", line 467, in _mp_worker
#     return getattr(self, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Tolga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas_ta\core.py", line 1225, in mcgd
#     result = mcgd(close=close, length=length, offset=offset, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Tolga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas_ta\overlap\mcgd.py", line 24, in mcgd
#     mcg_ds = close[:1].append(mcg_cell[1:])
#              ^^^^^^^^^^^^^^^^
#   File "C:\Users\Tolga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py", line 6204, in __getattr__
#     return object.__getattribute__(self, name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'Series' object has no attribute 'append'
# """
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 19
#      16 df.index.name = "datetime"
#      18 # Now your original code will work:
# ---> 19 df.ta.strategy()
#      20 df.ta.strategy("all")
#      21 df.ta.strategy(ta.AllStrategy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas_ta\core.py:792, in AnalysisIndicators.strategy(self, *args, **kwargs)
#     789         self._last_run = get_time(self.exchange, to_string=True)
#     791 # Apply prefixes/suffixes and appends indicator results to the  DataFrame
# --> 792 [self._post_process(r, **kwargs) for r in results]
#     794 if verbose:
#     795     print(f"[i] Total indicators: {len(ta)}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas_ta\core.py:792, in <listcomp>(.0)
#     789         self._last_run = get_time(self.exchange, to_string=True)
#     791 # Apply prefixes/suffixes and appends indicator results to the  DataFrame
# --> 792 [self._post_process(r, **kwargs) for r in results]
#     794 if verbose:
#     795     print(f"[i] Total indicators: {len(ta)}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\pool.py:423, in <genexpr>(.0)
#     415 result = IMapIterator(self)
#     416 self._taskqueue.put(
#     417     (
#     418         self._guarded_task_generation(result._job,
#    (...)
#     421         result._set_length
#     422     ))
# --> 423 return (item for chunk in result for item in chunk)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\pool.py:873, in IMapIterator.next(self, timeout)
#     871 if success:
#     872     return value
# --> 873 raise value
#
# AttributeError: 'Series' object has no attribute 'append'
