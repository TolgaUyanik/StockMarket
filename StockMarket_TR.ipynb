# %% [markdown]
# # TR Stock Market
# - If this error happens change the period to 6 months.
# HTTP Error 404:
# $ISCTR: possibly delisted; no price data found  (period=2y) (Yahoo error = "No data found, symbol may be delisted")
# No historical data for ISCTR, skipping...
#
# - MACD doesn't clear in this code.
# - SMA and other moving average indicators will add.

# %%
import yfinance as yf, pandas as pd, matplotlib.pyplot as plt, pandas_ta as ta, numpy as np
import os, math, time, warnings
import Classic_Analysis
from Classic_Analysis import portfolio, bist,bist100 #endeks, sectors, portfolio, nasdaq, Coin, bist100, global_Markets,US_stocks
from datetime import datetime, timedelta
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)        # Don't wrap columns
pd.set_option('display.max_colwidth', None) # Show full content of each column
pd.set_option('display.float_format', lambda x: '%.2f' % x)
#portfolio = ["MGROS.IS","KCHOL.IS","THYAO.IS","KRDMD.IS","CCOLA.IS","BRSAN.IS","ZOREN.IS","TTRAK.IS","AEFES.IS","FROTO.IS","ALCAR.IS"]

# %%
Classic_Analysis.classic_analysis(bist100,timespan="1h",period="1y")
# Out:
# 94/94 Downloaded ZOREN.IS data
# Download process is done!
# Saving Process Failed!
# Stock Market Data Processing is Done!

# %%
df2 = pd.read_csv(f"CSVs/Results last.csv")
#df2[["symbol","CPrice","kama","EMA_200"]] #
df2[["symbol",'RSI', 'ADX', 'CCI', 'ROC', 'ATR', 'OBV', 'CMF',
'AD', 'MFI', 'MACD', 'MACD_signal', 'MACD_Hist', 'MACDAS',
'MACDAS_Signal', 'BB_Middle', 'BB_Upper', 'BB_Lower', 'BB_%B',
'BB_BWidth', 'FWMA', 'VWAP', "SMA_14",	"SMA_20",	"SMA_50",	"SMA_100",	"SMA_200",'EMA_200', 'Supertrend', 'st_way',
'YF%','MACDAS-dif', 'change','BB_Pot', 'BB_Opt', 'TrendWay', 'Cloud_Position', 'TK_Cross']]
# Out:
#       symbol   RSI   ADX     CCI   ROC   ATR            OBV   CMF  \
# 0   MGROS.IS 20.36 30.88 -122.09 -4.32  4.00    15185540.00 -0.33
# 1   KCHOL.IS 31.03 26.82  -74.90 -3.01  1.84   895993459.00 -0.24
# 2   THYAO.IS 22.65 26.40 -104.81 -4.35  2.80   688551811.00 -0.23
# 3   KRDMD.IS 21.65 41.03  -87.07 -4.59  0.28  1695431125.00 -0.36
# 4   CCOLA.IS 46.15 28.64  -26.76 -1.12  0.42     5359914.00 -0.20
# 5   BRSAN.IS 31.81 16.43  -89.24 -2.76  6.61    -3041647.00 -0.27
# 6   ZOREN.IS 24.32 27.52 -105.87 -6.12  0.05   456260664.00 -0.28
# 7   TTRAK.IS 26.85 42.73  -87.01 -1.54  4.63      800231.00  0.05
# 8   AEFES.IS 18.49 38.63  -88.71 -3.72  0.15   149339260.00 -0.38
# 9   FROTO.IS 42.76 22.73  -72.87 -0.95  1.22    68267832.00  0.02
# 10  ALCAR.IS 35.54 21.48  -74.24 -3.16 12.68     1259074.00 -0.19
# 11  ISCTR.IS 40.87 15.30  -59.01 -3.25  0.17 12484465783.00 -0.27
#
#               AD   MFI  MACD  MACD_signal  MACD_Hist  MACDAS  MACDAS_Signal  \
# 0    -7292272.12 25.70 -6.45        -5.22      -1.23   -1.23          -0.85
# 1   -33735544.28 56.90 -2.07        -2.01      -0.06   -0.06          -0.05
# 2   -30441625.45 43.27 -4.83        -4.13      -0.70   -0.70          -0.68
# 3  -264488826.55 24.76 -0.45        -0.40      -0.05   -0.05          -0.05
# 4   -13098589.31 63.47 -0.33        -0.33      -0.01   -0.01          -0.07
# 5   -48947947.60 52.12 -6.08        -5.96      -0.11   -0.11          -0.36
# 6   -43648644.45 11.11 -0.07        -0.05      -0.02   -0.02          -0.02
# 7    -7362121.44 54.03 -5.40        -5.24      -0.17   -0.17          -0.22
# 8  -145826536.59 32.41 -0.28        -0.28      -0.00   -0.00          -0.01
# 9    -3450120.54 53.14 -0.42        -0.37      -0.05   -0.05           0.04
# 10   -1210402.65 60.81 -9.57        -7.47      -2.10   -2.10          -1.98
# 11 1633797139.93 65.82 -0.11        -0.10      -0.01   -0.01           0.00
#
#     BB_Middle  BB_Upper  BB_Lower  BB_%B  BB_BWidth   FWMA   VWAP  SMA_14  \
# 0      452.20    469.25    435.15   0.07       7.54 440.07 443.15  448.55
# 1      167.39    172.93    161.85   0.21       6.61 164.40 164.40  166.14
# 2      316.95    328.69    305.21   0.12       7.41 309.11 310.91  314.46
# 3       26.54     27.74     25.34   0.17       9.02  25.84  25.92   26.26
# 4       47.94     49.39     46.49   0.42       6.04  47.47  47.25   47.57
# 5      458.45    471.41    445.49   0.14       5.65 451.03 452.49  455.29
# 6        3.68      3.91      3.46   0.15      12.00   3.54   3.56    3.63
# 7      581.85    594.26    569.44   0.18       4.27 574.60 575.63  578.68
# 8       14.90     15.52     14.28   0.18       8.28  14.55  14.59   14.75
# 9      105.36    107.09    103.63   0.31       3.28 104.70 104.79  105.46
# 10     983.17   1014.21    952.14   0.21       6.31 964.78 966.60  978.11
# 11      13.57     14.01     13.13   0.28       6.47  13.37  13.35   13.51
#
#     SMA_20  SMA_50  SMA_100  SMA_200  EMA_200  Supertrend  st_way   YF%  \
# 0   452.20  460.94   477.31   494.39   486.09      450.49      -1 19.70
# 1   167.39  171.37   179.29   180.19   177.23      169.88      -1 41.57
# 2   316.95  324.49   332.41   329.60   324.60      316.50      -1 61.62
# 3    26.54   27.18    28.71    28.65    28.15       26.64      -1 35.66
# 4    47.94   48.29    49.58    50.09    49.65       48.33      -1 18.22
# 5   458.45  470.93   472.58   427.72   435.66      469.14      -1 50.00
# 6     3.68    3.74     3.88     3.76     3.73        3.66      -1 39.25
# 7   581.85  592.11   610.73   617.57   608.71      587.02      -1  7.41
# 8    14.90   15.46    16.41    16.87    16.32       14.94      -1 11.44
# 9   105.36  106.17   110.14   109.13   107.19      107.68      -1 67.81
# 10  983.17  995.59  1005.86   998.53   996.26      997.50      -1 25.59
# 11   13.57   13.77    14.47    14.62    14.40       13.82      -1 51.00
#
#     MACDAS-dif  change  BB_Pot  BB_Opt  TrendWay Cloud_Position TK_Cross
# 0        -0.38   -3.05    7.38   -0.42     lower    Below_Cloud  Bearish
# 1        -0.01   -0.06    5.12   -1.61     lower    Below_Cloud  Bearish
# 2        -0.02   -1.36    6.37   -1.23     lower    Below_Cloud  Bearish
# 3         0.01   -1.53    7.68   -1.61     lower    Below_Cloud  Bearish
# 4         0.07    0.93    3.63   -2.45     lower    Below_Cloud  Bearish
# 5         0.25   -0.06    4.87   -0.89  no-trend    Below_Cloud  Bullish
# 6        -0.00   -4.59   10.62   -1.90     lower    Below_Cloud  Bearish
# 7         0.05   -0.78    3.62   -0.71     lower    Below_Cloud  Bearish
# 8         0.01   -0.96    7.02   -1.49     lower    Below_Cloud  Bearish
# 9        -0.10   -0.28    1.41   -1.86     lower    Below_Cloud  Bearish
# 10       -0.13    1.16    5.54   -0.92     lower    Below_Cloud  Bearish
# 11       -0.01    0.07    4.54   -2.01  no-trend    Below_Cloud  Bearish

# %%
# # Avarage based indicators
# trend = df2[df2["EMA_200"]>df2["SMA_14"]]
# trend = df2[df2["EMA_200"]<df2["CPrice"]]
# trend
# Example: filter rows where EMA_200 > SMA_14
trend1 = df2[df2["EMA_200"] > df2["SMA_14"]]
# Example: filter rows where EMA_200 < Current Price
trend2 = df2[df2["EMA_200"] < df2["CPrice"]]
# Combine both conditions
trend = df2[(df2["EMA_200"] > df2["SMA_14"]) & (df2["EMA_200"] < df2["CPrice"])]
print(trend.tail())
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, symbol, priceToBook, CPrice, targetHighPrice, targetLowPrice, targetMeanPrice, targetMedianPrice, bookValue, open, dayLow, dayHigh, recommendationKey, fiftyTwoWeekLow, fiftyTwoWeekHigh, RSI, ADX, CCI, ROC, ATR, OBV, CMF, AD, MFI, MACD, MACD_signal, MACD_Hist, MACDAS, MACDAS_Signal, BB_Middle, BB_Upper, BB_Lower, BB_%B, BB_BWidth, FWMA, VWAP, kama, EMA_200, Supertrend, st_way, Stoch_K, Stoch_D, StochRSI_K, StochRSI_D, Tenkan, Kijun, Senkou_A, Senkou_B, Chikou, SMA_14, SMA_20, SMA_50, SMA_100, SMA_200, time, YF%, MACDAS-dif, change, BB_Pot, BB_Opt, TrendWay, Cloud_Position, TK_Cross]
# Index: []

# %%
cheap = df2.copy()
cheap = cheap[cheap["RSI"] < 40]
#cheap = cheap[cheap["ADX"] < -80]
#cheap = cheap[cheap["CCI"] < -80]
cheap
# Out:
#     Unnamed: 0    symbol  priceToBook  CPrice  targetHighPrice  \
# 0            0  MGROS.IS         1.18  437.00           982.00
# 1            1  KCHOL.IS         0.70  164.50           325.20
# 2            2  THYAO.IS        22.48  309.00           586.00
# 3            3  KRDMD.IS         0.49   25.76            51.00
# 5            5  BRSAN.IS         1.85  449.50              NaN
# 6            6  ZOREN.IS         0.28    3.53             4.55
# 7            7  TTRAK.IS         3.79  573.50           850.00
# 8            8  AEFES.IS         0.92   14.50            27.40
# 10          10  ALCAR.IS         5.14  961.00              NaN
#
#     targetLowPrice  targetMeanPrice  targetMedianPrice  bookValue   open  \
# 0           650.00           764.58             751.70     369.11 450.75
# 1           240.00           282.88             279.20     234.75 164.60
# 2           331.00           459.63             453.45      13.74 313.25
# 3            29.09            39.53              39.37      52.05  26.16
# 5              NaN              NaN                NaN     242.91 449.75
# 6             4.55             4.55               4.55      12.57   3.70
# 7           650.00           749.62             742.70     151.49 578.00
# 8            16.00            23.23              24.75      15.85  14.64
# 10             NaN              NaN                NaN     186.97 950.00
#
#     dayLow  dayHigh recommendationKey  fiftyTwoWeekLow  fiftyTwoWeekHigh  \
# 0   437.00   452.25        strong_buy           397.00            600.00
# 1   163.10   166.70        strong_buy           133.70            207.80
# 2   307.50   315.50        strong_buy           249.20            346.25
# 3    25.74    26.32              none            21.16             34.06
# 5   443.00   458.25              none           297.50            601.50
# 6     3.51     3.70              none             2.80              4.66
# 7   570.00   579.00              none           550.00            867.00
# 8    14.50    14.75              none            13.25             24.18
# 10  950.00   988.00              none           809.00           1403.00
#
#      RSI   ADX     CCI   ROC   ATR           OBV   CMF            AD   MFI  \
# 0  20.36 30.88 -122.09 -4.32  4.00   15185540.00 -0.33   -7292272.12 25.70
# 1  31.03 26.82  -74.90 -3.01  1.84  895993459.00 -0.24  -33735544.28 56.90
# 2  22.65 26.40 -104.81 -4.35  2.80  688551811.00 -0.23  -30441625.45 43.27
# 3  21.65 41.03  -87.07 -4.59  0.28 1695431125.00 -0.36 -264488826.55 24.76
# 5  31.81 16.43  -89.24 -2.76  6.61   -3041647.00 -0.27  -48947947.60 52.12
# 6  24.32 27.52 -105.87 -6.12  0.05  456260664.00 -0.28  -43648644.45 11.11
# 7  26.85 42.73  -87.01 -1.54  4.63     800231.00  0.05   -7362121.44 54.03
# 8  18.49 38.63  -88.71 -3.72  0.15  149339260.00 -0.38 -145826536.59 32.41
# 10 35.54 21.48  -74.24 -3.16 12.68    1259074.00 -0.19   -1210402.65 60.81
#
#     MACD  MACD_signal  MACD_Hist  MACDAS  MACDAS_Signal  BB_Middle  BB_Upper  \
# 0  -6.45        -5.22      -1.23   -1.23          -0.85     452.20    469.25
# 1  -2.07        -2.01      -0.06   -0.06          -0.05     167.39    172.93
# 2  -4.83        -4.13      -0.70   -0.70          -0.68     316.95    328.69
# 3  -0.45        -0.40      -0.05   -0.05          -0.05      26.54     27.74
# 5  -6.08        -5.96      -0.11   -0.11          -0.36     458.45    471.41
# 6  -0.07        -0.05      -0.02   -0.02          -0.02       3.68      3.91
# 7  -5.40        -5.24      -0.17   -0.17          -0.22     581.85    594.26
# 8  -0.28        -0.28      -0.00   -0.00          -0.01      14.90     15.52
# 10 -9.57        -7.47      -2.10   -2.10          -1.98     983.17   1014.21
#
#     BB_Lower  BB_%B  BB_BWidth   FWMA   VWAP   kama  EMA_200  Supertrend  \
# 0     435.15   0.07       7.54 440.07 443.15 443.38   486.09      450.49
# 1     161.85   0.21       6.61 164.40 164.40 165.57   177.23      169.88
# 2     305.21   0.12       7.41 309.11 310.91 311.90   324.60      316.50
# 3      25.34   0.17       9.02  25.84  25.92  25.89    28.15       26.64
# 5     445.49   0.14       5.65 451.03 452.49 455.27   435.66      469.14
# 6       3.46   0.15      12.00   3.54   3.56   3.54     3.73        3.66
# 7     569.44   0.18       4.27 574.60 575.63 577.23   608.71      587.02
# 8      14.28   0.18       8.28  14.55  14.59  14.56    16.32       14.94
# 10    952.14   0.21       6.31 964.78 966.60 975.63   996.26      997.50
#
#     st_way  Stoch_K  Stoch_D  StochRSI_K  StochRSI_D  Tenkan   Kijun  \
# 0       -1     4.21     4.06        0.00        0.00  459.50  469.38
# 1       -1    11.11    11.61       37.25       32.09  167.90  175.55
# 2       -1     3.77     3.46        4.86        2.93  326.75  327.62
# 3       -1     5.22     6.02        8.64        8.10   26.96   27.66
# 5       -1    29.61    29.27       60.51       46.77  481.25  480.00
# 6       -1     4.60     4.90        3.69        1.23    3.71    3.75
# 7       -1    19.38    19.24       28.54       17.48  592.75  600.00
# 8       -1     5.49     6.32       15.92       15.85   15.34   16.16
# 10      -1    21.03    19.40       12.71        6.41  993.75 1007.00
#
#     Senkou_A  Senkou_B  Chikou  SMA_14  SMA_20  SMA_50  SMA_100  SMA_200  \
# 0     487.12    493.12     NaN  448.55  452.20  460.94   477.31   494.39
# 1     185.50    186.40     NaN  166.14  167.39  171.37   179.29   180.19
# 2     338.00    340.00     NaN  314.46  316.95  324.49   332.41   329.60
# 3      29.60     30.35     NaN   26.26   26.54   27.18    28.71    28.65
# 5     496.94    460.00     NaN  455.29  458.45  470.93   472.58   427.72
# 6       3.87      4.10     NaN    3.63    3.68    3.74     3.88     3.76
# 7     621.12    633.00     NaN  578.68  581.85  592.11   610.73   617.57
# 8      17.12     17.40     NaN   14.75   14.90   15.46    16.41    16.87
# 10   1023.50   1016.00     NaN  978.11  983.17  995.59  1005.86   998.53
#
#                           time   YF%  MACDAS-dif  change  BB_Pot  BB_Opt  \
# 0   2025-09-09 01:56:21.415003 19.70       -0.38   -3.05    7.38   -0.42
# 1   2025-09-09 01:56:21.415003 41.57       -0.01   -0.06    5.12   -1.61
# 2   2025-09-09 01:56:21.415003 61.62       -0.02   -1.36    6.37   -1.23
# 3   2025-09-09 01:56:21.415003 35.66        0.01   -1.53    7.68   -1.61
# 5   2025-09-09 01:56:21.415003 50.00        0.25   -0.06    4.87   -0.89
# 6   2025-09-09 01:56:21.415003 39.25       -0.00   -4.59   10.62   -1.90
# 7   2025-09-09 01:56:21.415003  7.41        0.05   -0.78    3.62   -0.71
# 8   2025-09-09 01:56:21.415003 11.44        0.01   -0.96    7.02   -1.49
# 10  2025-09-09 01:56:21.415003 25.59       -0.13    1.16    5.54   -0.92
#
#     TrendWay Cloud_Position TK_Cross
# 0      lower    Below_Cloud  Bearish
# 1      lower    Below_Cloud  Bearish
# 2      lower    Below_Cloud  Bearish
# 3      lower    Below_Cloud  Bearish
# 5   no-trend    Below_Cloud  Bullish
# 6      lower    Below_Cloud  Bearish
# 7      lower    Below_Cloud  Bearish
# 8      lower    Below_Cloud  Bearish
# 10     lower    Below_Cloud  Bearish

# %%
dfport= df2[df2["symbol"].isin(portfolio)]
dfport
# Out:
#     Unnamed: 0    symbol  priceToBook  CPrice  targetHighPrice  \
# 0            0  MGROS.IS         1.18  437.00           982.00
# 1            1  KCHOL.IS         0.70  164.50           325.20
# 2            2  THYAO.IS        22.48  309.00           586.00
# 3            3  KRDMD.IS         0.49   25.76            51.00
# 4            4  CCOLA.IS         2.14   47.66            85.40
# 5            5  BRSAN.IS         1.85  449.50              NaN
# 6            6  ZOREN.IS         0.28    3.53             4.55
# 7            7  TTRAK.IS         3.79  573.50           850.00
# 8            8  AEFES.IS         0.92   14.50            27.40
# 9            9  FROTO.IS         2.64  105.60           224.00
# 10          10  ALCAR.IS         5.14  961.00              NaN
# 11          11  ISCTR.IS         0.93   13.40            21.47
#
#     targetLowPrice  targetMeanPrice  targetMedianPrice  bookValue   open  \
# 0           650.00           764.58             751.70     369.11 450.75
# 1           240.00           282.88             279.20     234.75 164.60
# 2           331.00           459.63             453.45      13.74 313.25
# 3            29.09            39.53              39.37      52.05  26.16
# 4            68.30            75.85              75.00      22.32  47.22
# 5              NaN              NaN                NaN     242.91 449.75
# 6             4.55             4.55               4.55      12.57   3.70
# 7           650.00           749.62             742.70     151.49 578.00
# 8            16.00            23.23              24.75      15.85  14.64
# 9           109.86           146.54             143.00      40.03 105.90
# 10             NaN              NaN                NaN     186.97 950.00
# 11           13.00            17.40              16.95      14.42  13.39
#
#     dayLow  dayHigh recommendationKey  fiftyTwoWeekLow  fiftyTwoWeekHigh  \
# 0   437.00   452.25        strong_buy           397.00            600.00
# 1   163.10   166.70        strong_buy           133.70            207.80
# 2   307.50   315.50        strong_buy           249.20            346.25
# 3    25.74    26.32              none            21.16             34.06
# 4    46.40    47.78              none            42.94             68.85
# 5   443.00   458.25              none           297.50            601.50
# 6     3.51     3.70              none             2.80              4.66
# 7   570.00   579.00              none           550.00            867.00
# 8    14.50    14.75              none            13.25             24.18
# 9   103.40   106.60              none            78.85            118.30
# 10  950.00   988.00              none           809.00           1403.00
# 11   13.23    13.65               buy            10.07             16.60
#
#      RSI   ADX     CCI   ROC   ATR            OBV   CMF            AD   MFI  \
# 0  20.36 30.88 -122.09 -4.32  4.00    15185540.00 -0.33   -7292272.12 25.70
# 1  31.03 26.82  -74.90 -3.01  1.84   895993459.00 -0.24  -33735544.28 56.90
# 2  22.65 26.40 -104.81 -4.35  2.80   688551811.00 -0.23  -30441625.45 43.27
# 3  21.65 41.03  -87.07 -4.59  0.28  1695431125.00 -0.36 -264488826.55 24.76
# 4  46.15 28.64  -26.76 -1.12  0.42     5359914.00 -0.20  -13098589.31 63.47
# 5  31.81 16.43  -89.24 -2.76  6.61    -3041647.00 -0.27  -48947947.60 52.12
# 6  24.32 27.52 -105.87 -6.12  0.05   456260664.00 -0.28  -43648644.45 11.11
# 7  26.85 42.73  -87.01 -1.54  4.63      800231.00  0.05   -7362121.44 54.03
# 8  18.49 38.63  -88.71 -3.72  0.15   149339260.00 -0.38 -145826536.59 32.41
# 9  42.76 22.73  -72.87 -0.95  1.22    68267832.00  0.02   -3450120.54 53.14
# 10 35.54 21.48  -74.24 -3.16 12.68     1259074.00 -0.19   -1210402.65 60.81
# 11 40.87 15.30  -59.01 -3.25  0.17 12484465783.00 -0.27 1633797139.93 65.82
#
#     MACD  MACD_signal  MACD_Hist  MACDAS  MACDAS_Signal  BB_Middle  BB_Upper  \
# 0  -6.45        -5.22      -1.23   -1.23          -0.85     452.20    469.25
# 1  -2.07        -2.01      -0.06   -0.06          -0.05     167.39    172.93
# 2  -4.83        -4.13      -0.70   -0.70          -0.68     316.95    328.69
# 3  -0.45        -0.40      -0.05   -0.05          -0.05      26.54     27.74
# 4  -0.33        -0.33      -0.01   -0.01          -0.07      47.94     49.39
# 5  -6.08        -5.96      -0.11   -0.11          -0.36     458.45    471.41
# 6  -0.07        -0.05      -0.02   -0.02          -0.02       3.68      3.91
# 7  -5.40        -5.24      -0.17   -0.17          -0.22     581.85    594.26
# 8  -0.28        -0.28      -0.00   -0.00          -0.01      14.90     15.52
# 9  -0.42        -0.37      -0.05   -0.05           0.04     105.36    107.09
# 10 -9.57        -7.47      -2.10   -2.10          -1.98     983.17   1014.21
# 11 -0.11        -0.10      -0.01   -0.01           0.00      13.57     14.01
#
#     BB_Lower  BB_%B  BB_BWidth   FWMA   VWAP   kama  EMA_200  Supertrend  \
# 0     435.15   0.07       7.54 440.07 443.15 443.38   486.09      450.49
# 1     161.85   0.21       6.61 164.40 164.40 165.57   177.23      169.88
# 2     305.21   0.12       7.41 309.11 310.91 311.90   324.60      316.50
# 3      25.34   0.17       9.02  25.84  25.92  25.89    28.15       26.64
# 4      46.49   0.42       6.04  47.47  47.25  47.50    49.65       48.33
# 5     445.49   0.14       5.65 451.03 452.49 455.27   435.66      469.14
# 6       3.46   0.15      12.00   3.54   3.56   3.54     3.73        3.66
# 7     569.44   0.18       4.27 574.60 575.63 577.23   608.71      587.02
# 8      14.28   0.18       8.28  14.55  14.59  14.56    16.32       14.94
# 9     103.63   0.31       3.28 104.70 104.79 105.38   107.19      107.68
# 10    952.14   0.21       6.31 964.78 966.60 975.63   996.26      997.50
# 11     13.13   0.28       6.47  13.37  13.35  13.59    14.40       13.82
#
#     st_way  Stoch_K  Stoch_D  StochRSI_K  StochRSI_D  Tenkan   Kijun  \
# 0       -1     4.21     4.06        0.00        0.00  459.50  469.38
# 1       -1    11.11    11.61       37.25       32.09  167.90  175.55
# 2       -1     3.77     3.46        4.86        2.93  326.75  327.62
# 3       -1     5.22     6.02        8.64        8.10   26.96   27.66
# 4       -1    47.67    35.35       80.01       49.34   47.92   48.17
# 5       -1    29.61    29.27       60.51       46.77  481.25  480.00
# 6       -1     4.60     4.90        3.69        1.23    3.71    3.75
# 7       -1    19.38    19.24       28.54       17.48  592.75  600.00
# 8       -1     5.49     6.32       15.92       15.85   15.34   16.16
# 9       -1    22.64    21.02        8.61       11.94  104.65  106.60
# 10      -1    21.03    19.40       12.71        6.41  993.75 1007.00
# 11      -1    12.09    11.33       26.02       21.03   13.12   14.07
#
#     Senkou_A  Senkou_B  Chikou  SMA_14  SMA_20  SMA_50  SMA_100  SMA_200  \
# 0     487.12    493.12     NaN  448.55  452.20  460.94   477.31   494.39
# 1     185.50    186.40     NaN  166.14  167.39  171.37   179.29   180.19
# 2     338.00    340.00     NaN  314.46  316.95  324.49   332.41   329.60
# 3      29.60     30.35     NaN   26.26   26.54   27.18    28.71    28.65
# 4      49.76     51.40     NaN   47.57   47.94   48.29    49.58    50.09
# 5     496.94    460.00     NaN  455.29  458.45  470.93   472.58   427.72
# 6       3.87      4.10     NaN    3.63    3.68    3.74     3.88     3.76
# 7     621.12    633.00     NaN  578.68  581.85  592.11   610.73   617.57
# 8      17.12     17.40     NaN   14.75   14.90   15.46    16.41    16.87
# 9     111.65    113.45     NaN  105.46  105.36  106.17   110.14   109.13
# 10   1023.50   1016.00     NaN  978.11  983.17  995.59  1005.86   998.53
# 11     15.13     15.23     NaN   13.51   13.57   13.77    14.47    14.62
#
#                           time   YF%  MACDAS-dif  change  BB_Pot  BB_Opt  \
# 0   2025-09-09 01:56:21.415003 19.70       -0.38   -3.05    7.38   -0.42
# 1   2025-09-09 01:56:21.415003 41.57       -0.01   -0.06    5.12   -1.61
# 2   2025-09-09 01:56:21.415003 61.62       -0.02   -1.36    6.37   -1.23
# 3   2025-09-09 01:56:21.415003 35.66        0.01   -1.53    7.68   -1.61
# 4   2025-09-09 01:56:21.415003 18.22        0.07    0.93    3.63   -2.45
# 5   2025-09-09 01:56:21.415003 50.00        0.25   -0.06    4.87   -0.89
# 6   2025-09-09 01:56:21.415003 39.25       -0.00   -4.59   10.62   -1.90
# 7   2025-09-09 01:56:21.415003  7.41        0.05   -0.78    3.62   -0.71
# 8   2025-09-09 01:56:21.415003 11.44        0.01   -0.96    7.02   -1.49
# 9   2025-09-09 01:56:21.415003 67.81       -0.10   -0.28    1.41   -1.86
# 10  2025-09-09 01:56:21.415003 25.59       -0.13    1.16    5.54   -0.92
# 11  2025-09-09 01:56:21.415003 51.00       -0.01    0.07    4.54   -2.01
#
#     TrendWay Cloud_Position TK_Cross
# 0      lower    Below_Cloud  Bearish
# 1      lower    Below_Cloud  Bearish
# 2      lower    Below_Cloud  Bearish
# 3      lower    Below_Cloud  Bearish
# 4      lower    Below_Cloud  Bearish
# 5   no-trend    Below_Cloud  Bullish
# 6      lower    Below_Cloud  Bearish
# 7      lower    Below_Cloud  Bearish
# 8      lower    Below_Cloud  Bearish
# 9      lower    Below_Cloud  Bearish
# 10     lower    Below_Cloud  Bearish
# 11  no-trend    Below_Cloud  Bearish

# %%
bullish = df2.copy()
bullish = bullish[bullish["TK_Cross"] == "Bullish"]
#bullish = bullish[bullish["Cloud_Position"] == "Above_Cloud"]
bullish = bullish[bullish["st_way"] > 0]
bullish = bullish[bullish["ADX"] > 20]
bullish = bullish[bullish["RSI"] < 60]
bullish = bullish[bullish["CPrice"]>bullish["kama"]]
bullish = bullish[bullish["BB_BWidth"]>10]
bullish = bullish[["symbol",'BB_BWidth', 'BB_%B',"YF%","RSI","ADX", "CCI","st_way","Supertrend","kama","CPrice","change","ROC","EMA_200"]]
bullish
# Out:
# Empty DataFrame
# Columns: [symbol, BB_BWidth, BB_%B, YF%, RSI, ADX, CCI, st_way, Supertrend, kama, CPrice, change, ROC, EMA_200]
# Index: []

# %%
#If this one works write portfolio as same format.
XU100 = df2.copy()
XU100 = XU100[XU100["symbol"].isin(bist100)]
XU100 = XU100.sort_values(by="RSI", ascending=True)
XU100.head(50)
XU100.to_csv(f"CSVs/XU100 last.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 #If this one works write portfolio as same format.
#       2 XU100 = df2.copy()
# ----> 3 XU100 = XU100[XU100["symbol"].isin(bist100)]
#       4 XU100 = XU100.sort_values(by="RSI", ascending=True)
#       5 XU100.head(50)
#
# NameError: name 'bist100' is not defined

# %%
import pandas as pd

def calculate_buy_sell_points(stock_data: pd.Series):
    """
    Calculates buy and sell points for a single stock based on technical indicators.

    Args:
        stock_data (pd.Series): A single row of a DataFrame containing stock indicator data.

    Returns:
        tuple: A tuple containing the total buy points and total sell points.
    """
    buy_points = 0
    sell_points = 0
    
    # RSI: Momentum oscillator indicating overbought/oversold.
    # Buy: Oversold condition.
    if stock_data['RSI'] < 30:
        buy_points += 1
    # Sell: Overbought condition.
    elif stock_data['RSI'] > 70:
        sell_points += 1

    # MFI (Money Flow Index): Volume-weighted RSI.
    # Buy: Oversold condition.
    if stock_data['MFI'] < 20:
        buy_points += 1
    # Sell: Overbought condition.
    elif stock_data['MFI'] > 80:
        sell_points += 1
        
    # MACD: Moving average crossover.
    # Buy: MACD line crosses above signal line.
    if stock_data['MACD'] > stock_data['MACD_signal']:
        buy_points += 1
    # Sell: MACD line crosses below signal line.
    elif stock_data['MACD'] < stock_data['MACD_signal']:
        sell_points += 1

    # Stochastic Oscillator: Compares close price to its high/low range.
    # Buy: Bullish crossover in the oversold zone.
    if stock_data['Stoch_K'] > stock_data['Stoch_D'] and stock_data['Stoch_K'] < 20:
        buy_points += 1
    # Sell: Bearish crossover in the overbought zone.
    elif stock_data['Stoch_K'] < stock_data['Stoch_D'] and stock_data['Stoch_K'] > 80:
        sell_points += 1
        
    # Supertrend: A trend-following indicator.
    # Buy: Upward trend direction.
    if stock_data['st_way'] == 1:
        buy_points += 2  # Stronger signal
    # Sell: Downward trend direction.
    elif stock_data['st_way'] == -1:
        sell_points += 2 # Stronger signal

    # Ichimoku Cloud: Multi-component system for trend identification.
    # Buy: Price is above the cloud.
    if stock_data['Cloud_Position'] == 'Above_Cloud':
        buy_points += 1
    # Sell: Price is below the cloud.
    elif stock_data['Cloud_Position'] == 'Below_Cloud':
        sell_points += 1
        
    # Bollinger Bands (%B): Shows where the price is relative to the bands.
    # Buy: Price is below the lower band.
    if stock_data['BB_%B'] < 0.0:
        buy_points += 1
    # Sell: Price is above the upper band.
    elif stock_data['BB_%B'] > 1.0:
        sell_points += 1
        
    # ADX (Average Directional Index) with CPrice and EMA_200 for trend direction.
    # This checks for a strong trend (ADX > 20) and combines it with a moving average crossover for direction.
    if stock_data['ADX'] > 20 and stock_data['CPrice'] > stock_data['EMA_200']:
        buy_points += 1
    elif stock_data['ADX'] > 20 and stock_data['CPrice'] < stock_data['EMA_200']:
        sell_points += 1

    return buy_points, sell_points

# Example usage with a sample data row from the notebook output
# Replace this with your actual dataframe
sample_data_row = pd.Series({
    'RSI': 63.10, 'MFI': 70.14, 'MACD': 11.14, 'MACD_signal': 9.94, 'Stoch_K': 79.27, 'Stoch_D': 79.97,
    'st_way': 1, 'Cloud_Position': 'Above_Cloud', 'BB_%B': 0.75, 'ADX': 22.66, 'CPrice': 529.00,
    'EMA_200': 495.27
})

buy_score, sell_score = calculate_buy_sell_points(sample_data_row)
print(f"Buy Score: {buy_score}")
print(f"Sell Score: {sell_score}")

# %%
df2[df2.symbol=="HRKET.IS"]

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import pandas_ta as ta
import numpy as np
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

def create_dual_charts_from_your_data(stock_list, period="6mo"):
    """
    Create dual charts (Ichimoku Cloud + MACD) using your existing data structure
    
    Parameters:
    stock_list: List of stock symbols
    period: Time period for data ('1y', '6mo', '3mo', etc.)
    """
    
    # Calculate grid dimensions
    n_stocks = len(stock_list)
    n_rows = n_stocks
    n_cols = 2  # Always 2 columns (Ichimoku + MACD)
    
    # Create figure with subplots
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 6*n_rows))
    fig.suptitle(f'Stock Analysis Dashboard - Ichimoku Cloud & MACD', fontsize=16, fontweight='bold')
    
    # Handle single stock case
    if n_stocks == 1:
        axes = axes.reshape(1, -1)
    
    # Dictionary to store all historical data (like in your classic_analysis function)
    stock_dict = {}
    
    for idx, symbol in enumerate(stock_list):
        try:
            print(f"Processing {symbol} ({idx+1}/{n_stocks})...")
            
            # Download stock data (using your method)
            ticker = yf.Ticker(symbol)
            historical_data = ticker.history(period=period)
            
            if historical_data.empty:
                print(f"No historical data for {symbol}, skipping...")
                continue
            
            # Calculate indicators using YOUR method from classic_analysis
            historical_data = calculate_your_indicators(historical_data)
            stock_dict[symbol] = historical_data
            
            # Plot Ichimoku Cloud (Left chart)
            ax_ichimoku = axes[idx, 0] if n_stocks > 1 else axes[0, 0]
            plot_ichimoku_cloud_your_data(ax_ichimoku, historical_data, symbol)
            
            # Plot MACD (Right chart)
            ax_macd = axes[idx, 1] if n_stocks > 1 else axes[0, 1]
            plot_macd_your_data(ax_macd, historical_data, symbol)
            
        except Exception as e:
            print(f"Error processing {symbol}: {str(e)}")
            continue
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.95)  # Adjust for main title
    plt.show()
    
    return fig, stock_dict

def calculate_your_indicators(historical_data):
    """Calculate indicators using YOUR exact method from classic_analysis"""
    
    # RSI
    historical_data['RSI'] = ta.rsi(historical_data['Close'], length=14)
    
    # ADX
    adx_data = ta.adx(historical_data['High'], historical_data['Low'], historical_data['Close'], length=14)
    historical_data['ADX'] = adx_data['ADX_14']
    
    # MACD - using YOUR method
    macd = ta.macd(historical_data['Close'], fast=12, slow=26, signal=9)
    historical_data = pd.concat([historical_data, macd], axis=1)
    
    # MACDAS - your custom indicator
    historical_data['MACDAS'] = historical_data['MACD_12_26_9'] - historical_data['MACDs_12_26_9']
    historical_data['MACDAS_Signal'] = historical_data['MACDAS'].ewm(span=9, adjust=False).mean()
    
    # CCI
    historical_data['CCI'] = ta.cci(historical_data['High'], historical_data['Low'], historical_data['Close'], length=20)
    
    # ROC
    historical_data['ROC'] = ta.roc(historical_data['Close'], length=12)
    
    # ATR
    historical_data['ATR'] = ta.atr(historical_data['High'], historical_data['Low'], historical_data['Close'], length=14)
    
    # MFI
    historical_data['MFI'] = ta.mfi(historical_data['High'], historical_data['Low'], historical_data['Close'], historical_data['Volume'], length=14)
    
    # FWMA
    historical_data["FWMA"] = ta.fwma(historical_data['Close'], length=14)
    
    # OBV
    historical_data['OBV'] = ta.obv(historical_data['Close'], historical_data['Volume'])
    
    # CMF
    historical_data['CMF'] = ta.cmf(historical_data['High'], historical_data['Low'], historical_data['Close'], historical_data['Volume'])
    
    # A/D Line
    historical_data['AD'] = ta.ad(historical_data['High'], historical_data['Low'], historical_data['Close'], historical_data['Volume'])
    
    # VWAP
    historical_data["VWAP"] = ta.vwap(historical_data['High'], historical_data['Low'], historical_data['Close'], historical_data['Volume'])
    
    # KAMA
    historical_data["kama"] = ta.kama(historical_data['Close'], length=14)
    
    # Supertrend
    supertrend = ta.supertrend(historical_data['High'], historical_data['Low'], historical_data['Close'], length=10, multiplier=3)
    historical_data['Supertrend'] = supertrend['SUPERT_10_3.0']
    historical_data['Supertrend_direction'] = supertrend['SUPERTd_10_3.0']
    
    # EMA 200
    historical_data['EMA_200'] = ta.ema(historical_data['Close'], length=200)
    
    # Calculate Ichimoku Cloud - YOUR method
    ichimoku = ta.ichimoku(historical_data['High'], historical_data['Low'], historical_data['Close'], 
                          tenkan=9, kijun=26, senkou=52, offset=26, include_chikou=True)
    
    # Handle Ichimoku data structure - YOUR method
    if isinstance(ichimoku, tuple) and len(ichimoku) >= 2:
        ichi_df1, ichi_df2 = ichimoku[0], ichimoku[1]
        historical_data['Tenkan'] = ichi_df1['ITS_9'] if 'ITS_9' in ichi_df1.columns else None
        historical_data['Kijun'] = ichi_df1['IKS_26'] if 'IKS_26' in ichi_df1.columns else None
        historical_data['Senkou_A'] = ichi_df1['ISA_9'] if 'ISA_9' in ichi_df1.columns else None
        historical_data['Senkou_B'] = ichi_df1['ISB_26'] if 'ISB_26' in ichi_df1.columns else None
        historical_data['Chikou'] = ichi_df2['ICS_26'] if 'ICS_26' in ichi_df2.columns else None
    else:
        # Fallback if structure is different
        historical_data['Tenkan'] = None
        historical_data['Kijun'] = None
        historical_data['Senkou_A'] = None
        historical_data['Senkou_B'] = None
        historical_data['Chikou'] = None
    
    # Calculate Stochastic Oscillator
    stoch = ta.stoch(historical_data['High'], historical_data['Low'], historical_data['Close'], k=14, d=3)
    historical_data['Stoch_K'] = stoch['STOCHk_14_3_3']
    historical_data['Stoch_D'] = stoch['STOCHd_14_3_3']
    
    # Calculate Stochastic RSI
    stochrsi = ta.stochrsi(historical_data['Close'], length=14, rsi_length=14, k=3, d=3)
    historical_data['StochRSI_K'] = stochrsi['STOCHRSIk_14_14_3_3']
    historical_data['StochRSI_D'] = stochrsi['STOCHRSId_14_14_3_3']

    # Calculate Bollinger Bands
    bollinger = ta.bbands(historical_data['Close'], length=20, std=2)
    historical_data['BB_Lower'] = bollinger.iloc[:, 0]  # Lower Band
    historical_data['BB_Middle'] = bollinger.iloc[:, 1]  # Middle Band
    historical_data['BB_Upper'] = bollinger.iloc[:, 2]  # Upper Band
    historical_data['BB_BWidth'] = bollinger.iloc[:, 3]  # Bandwidth
    historical_data['BB_%B'] = bollinger.iloc[:, 4]  # %B
    
    return historical_data

def plot_ichimoku_cloud_your_data(ax, data, symbol):
    """Plot Ichimoku Cloud chart using your data"""
    
    # Plot price
    ax.plot(data.index, data['Close'], label='Price', linewidth=2, color='black')
    
    # Check if Ichimoku data exists
    if data['Tenkan'].isna().all():
        ax.text(0.5, 0.5, f'No Ichimoku data available for {symbol}', 
                horizontalalignment='center', verticalalignment='center', 
                transform=ax.transAxes)
        ax.set_title(f'{symbol} - Ichimoku Cloud', fontweight='bold')
        return
    
    # Plot Ichimoku lines
    if not data['Tenkan'].isna().all():
        ax.plot(data.index, data['Tenkan'], label='Tenkan-sen (9)', color='red', linewidth=1)
    if not data['Kijun'].isna().all():
        ax.plot(data.index, data['Kijun'], label='Kijun-sen (26)', color='blue', linewidth=1)
    if not data['Chikou'].isna().all():
        ax.plot(data.index, data['Chikou'], label='Chikou Span', color='green', linewidth=1, alpha=0.7)
    
    # Plot cloud (Kumo)
    if not data['Senkou_A'].isna().all() and not data['Senkou_B'].isna().all():
        senkou_a = data['Senkou_A'].dropna()
        senkou_b = data['Senkou_B'].dropna()
        
        if not senkou_a.empty and not senkou_b.empty:
            # Align indices
            common_index = senkou_a.index.intersection(senkou_b.index)
            if not common_index.empty:
                senkou_a_aligned = senkou_a.loc[common_index]
                senkou_b_aligned = senkou_b.loc[common_index]
                
                # Fill cloud area
                ax.fill_between(common_index, senkou_a_aligned, senkou_b_aligned,
                               where=(senkou_a_aligned >= senkou_b_aligned), 
                               color='lightgreen', alpha=0.3, label='Bullish Cloud')
                ax.fill_between(common_index, senkou_a_aligned, senkou_b_aligned,
                               where=(senkou_a_aligned < senkou_b_aligned), 
                               color='lightcoral', alpha=0.3, label='Bearish Cloud')
                
                # Plot Senkou lines
                ax.plot(senkou_a.index, senkou_a, label='Senkou Span A', color='orange', linewidth=1, alpha=0.8)
                ax.plot(senkou_b.index, senkou_b, label='Senkou Span B', color='purple', linewidth=1, alpha=0.8)
    
    ax.set_title(f'{symbol} - Ichimoku Cloud', fontweight='bold')
    ax.set_ylabel('Price')
    ax.legend(loc='upper left', fontsize=8)
    ax.grid(True, alpha=0.3)
    ax.tick_params(axis='x', rotation=45)

def plot_macd_your_data(ax, data, symbol):
    """Plot MACD chart using your data structure"""
    
    # Check if MACD data exists
    if 'MACD_12_26_9' not in data.columns or data['MACD_12_26_9'].isna().all():
        ax.text(0.5, 0.5, f'No MACD data available for {symbol}', 
                horizontalalignment='center', verticalalignment='center', 
                transform=ax.transAxes)
        ax.set_title(f'{symbol} - MACD', fontweight='bold')
        return
    
    # Remove NaN values for plotting
    macd_data = data[['MACD_12_26_9', 'MACDs_12_26_9', 'MACDh_12_26_9']].dropna()
    
    if macd_data.empty:
        ax.text(0.5, 0.5, f'No MACD data available for {symbol}', 
                horizontalalignment='center', verticalalignment='center', 
                transform=ax.transAxes)
        ax.set_title(f'{symbol} - MACD', fontweight='bold')
        return
    
    # Plot MACD and Signal lines using YOUR column names
    ax.plot(macd_data.index, macd_data['MACD_12_26_9'], label='MACD', color='blue', linewidth=2)
    ax.plot(macd_data.index, macd_data['MACDs_12_26_9'], label='Signal', color='red', linewidth=2)
    
    # Plot histogram using YOUR column names
    histogram_values = macd_data['MACDh_12_26_9']
    colors = ['green' if x >= 0 else 'red' for x in histogram_values]
    ax.bar(macd_data.index, histogram_values, label='Histogram', 
           color=colors, alpha=0.6, width=1)
    
    # Add zero line
    ax.axhline(y=0, color='black', linestyle='-', alpha=0.5)
    
    ax.set_title(f'{symbol} - MACD', fontweight='bold')
    ax.set_ylabel('MACD')
    ax.legend(loc='upper left')
    ax.grid(True, alpha=0.3)
    ax.tick_params(axis='x', rotation=45)

# Example usage with your portfolio
portfolio = ["MGROS.IS","KCHOL.IS","THYAO.IS","KRDMD.IS","CCOLA.IS",
             "BRSAN.IS","ZOREN.IS","TTRAK.IS","AEFES.IS","FROTO.IS","ALCAR.IS"]

# Create charts for your portfolio
if __name__ == "__main__":
    # Create the dual charts using your data structure
    fig, stock_data_dict = create_dual_charts_from_your_data(portfolio, period="6mo")
    
    # You can access the historical data with all indicators for each stock:
    # stock_data_dict['MGROS.IS'] will contain all the calculated indicators
    
    # Save the figure if needed
    # plt.savefig(f'dual_charts_{datetime.now().strftime("%Y%m%d")}.png', dpi=300, bbox_inches='tight')

print("Dual chart system using your data structure is ready!")
print("Usage: create_dual_charts_from_your_data(portfolio, period='6mo')")
print("The function returns both the figure and a dictionary with all historical data and indicators.")
